# %% [markdown]
# <center><a href="https://www.nvidia.com/dli"> <img src="images/DLI_Header.png" alt="Header" style="width: 400px;"/> </a></center>

# %% [markdown]
# # Data Augmentation

# %% [markdown]
# So far, we've selected a model architecture that vastly improves the model's performance, as it is designed to recognize important features in the images. The validation accuracy is still lagging behind the training accuracy, which is a sign of overfitting: the model is getting confused by things it has not seen before when it tests against the validation dataset.
#
# In order to teach our model to be more robust when looking at new data, we're going to programmatically increase the size and variance in our dataset. This is known as [*data augmentation*](https://link.springer.com/article/10.1186/s40537-019-0197-0), a useful technique for many deep learning applications.
#
# The increase in size gives the model more images to learn from while training. The increase in variance helps the model ignore unimportant features and select only the features that are truly important in classification, allowing it to generalize better.

# %% [markdown]
# На данный момент мы выбрали архитектуру модели, которая значительно повышает производительность модели, поскольку она предназначена для распознавания важных особенностей изображений. Точность проверки по-прежнему отстает от точности обучения, что является признаком переобучения: модель путается из-за вещей, которых она раньше не видела, когда тестирует набор данных проверки.
#
# Чтобы научить нашу модель быть более надежной при просмотре новых данных, мы собираемся программно увеличить размер и дисперсию в нашем наборе данных. Это известно как [*увеличение данных*] (https://link.springer.com/article/10.1186/s40537-019-0197-0), полезный метод для многих приложений глубокого обучения.
#
# Увеличение размера дает модели больше изображений для изучения во время обучения. Увеличение дисперсии помогает модели игнорировать несущественные признаки и выбирать только те признаки, которые действительно важны для классификации, что позволяет ей лучше обобщать.

# %% [markdown]
# ## Objectives

# %% [markdown]
# * Augment the ASL dataset
# * Use the augmented data to train an improved model
# * Save the well-trained model to disk for use in deployment

# %%
 Дополнить набор данных ASL
 Используйте дополненные данные для обучения улучшенной модели
 Сохраните хорошо обученную модель на диск для использования в развертывании.
# Out:
#   File "<ipython-input-2-1cf140c7609f>", line 1
#     Дополнить набор данных ASL
#                   ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Preparing the Data

# %% [markdown]
# As we're in a new notebook, we will load and process our data again. To do this, execute the following cell:

# %%
import tensorflow.keras as keras
import pandas as pd

# Load in our data from CSV files
train_df = pd.read_csv("data/asl_data/sign_mnist_train.csv")
valid_df = pd.read_csv("data/asl_data/sign_mnist_valid.csv")

# Separate out our target values
y_train = train_df['label']
y_valid = valid_df['label']
del train_df['label']
del valid_df['label']

# Separate our our image vectors
x_train = train_df.values
x_valid = valid_df.values

# Turn our scalar targets into binary categories
num_classes = 24
y_train = keras.utils.to_categorical(y_train, num_classes)
y_valid = keras.utils.to_categorical(y_valid, num_classes)

# Normalize our image data
x_train = x_train / 255
x_valid = x_valid / 255

# Reshape the image data for the convolutional network
x_train = x_train.reshape(-1,28,28,1)
x_valid = x_valid.reshape(-1,28,28,1)

# %% [markdown]
# ## Model Creation

# %% [markdown]
# We will also need to create our model again. To do this, execute the following cell. You will notice this is the same model architecture as the last section:

# %% [markdown]
# Нам также нужно будет снова создать нашу модель. Для этого выполните следующую ячейку. Вы заметите, что это та же архитектура модели, что и в предыдущем разделе:

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Dense,
    Conv2D,
    MaxPool2D,
    Flatten,
    Dropout,
    BatchNormalization,
)

model = Sequential()
model.add(Conv2D(75, (3, 3), strides=1, padding="same", activation="relu", 
                 input_shape=(28, 28, 1)))
model.add(BatchNormalization())
model.add(MaxPool2D((2, 2), strides=2, padding="same"))
model.add(Conv2D(50, (3, 3), strides=1, padding="same", activation="relu"))
model.add(Dropout(0.2))
model.add(BatchNormalization())
model.add(MaxPool2D((2, 2), strides=2, padding="same"))
model.add(Conv2D(25, (3, 3), strides=1, padding="same", activation="relu"))
model.add(BatchNormalization())
model.add(MaxPool2D((2, 2), strides=2, padding="same"))
model.add(Flatten())
model.add(Dense(units=512, activation="relu"))
model.add(Dropout(0.3))
model.add(Dense(units=num_classes, activation="softmax"))

# %% [markdown]
# ## Data Augmentation

# %% [markdown]
# Before compiling the model, it's time to set up our data augmentation.
#
# Keras comes with an image augmentation class called `ImageDataGenerator`. We recommend checking out the [documentation here](https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator). It accepts a series of options for augmenting your data. Later in the course, we'll have you select a proper augmentation strategy. For now, take a look at the options we've selected below, and then execute the cell to create an instance of the class:

# %% [markdown]
# Перед компиляцией модели пришло время настроить аугментацию наших данных.
#
# Keras поставляется с классом увеличения изображения под названием «ImageDataGenerator». Мы рекомендуем ознакомиться с [документацией здесь] (https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator). Он принимает ряд опций для увеличения ваших данных. Позже в ходе курса мы попросим вас выбрать правильную стратегию усиления. А пока взгляните на параметры, которые мы выбрали ниже, а затем выполните ячейку, чтобы создать экземпляр класса:

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
    zoom_range=0.1,  # Randomly zoom image
    width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
    height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
    horizontal_flip=True,  # randomly flip images horizontally
    vertical_flip=False, # Don't randomly flip images vertically
)

# %% [markdown]
# Take a moment to think about why we would want to flip images horizontally, but not vertically. When you have an idea, reveal the text below.

# %% [markdown]
# `# SOLUTION` Our dataset is pictures of hands signing the alphabet. If we want to use this model to classify hand images later, it's unlikely that those hands are going to be upside-down, but, they might be left-handed. This kind of domain-specific reasoning can help make good decisions for your own deep learning applications.

# %% [markdown]
# `# РЕШЕНИЕ` Наш набор данных представляет собой изображения рук, подписывающих алфавит. Если мы позже захотим использовать эту модель для классификации изображений рук, маловероятно, что эти руки будут перевернутыми, но они могут быть левосторонними. Такой вид рассуждений, специфичных для предметной области, может помочь принять правильные решения для ваших собственных приложений глубокого обучения.

# %% [markdown]
# ## Batch Size
# Another benefit of the `ImageDataGenerator` is that it [batches](https://machinelearningmastery.com/how-to-control-the-speed-and-stability-of-training-neural-networks-with-gradient-descent-batch-size/) our data so that our model can train on a random sample.
#
# If the model is [truly random](http://sites.utexas.edu/sos/random/), meaning that the data is properly shuffled so it's fair like a deck of cards, then our sample can do a good job of representing all of our data even though it is a tiny fraction of the population. For each step of the training, the model will be dealt a new batch.
#
# In practice, a batch size of 32 and 64 does well. Run the cell below to see what kind of batches we'll be training our model with. Is our randomizer fairly randomizing? Are all of the images recognizable ASL letters?

# %% [markdown]
# Еще одним преимуществом ImageDataGenerator является то, что он [пакетно] размер партии/) наши данные, чтобы наша модель могла обучаться на случайной выборке.
#
# Если модель [действительно случайная](http://sites.utexas.edu/sos/random/), что означает, что данные правильно перетасованы, так что они справедливы, как колода карт, тогда наша выборка может хорошо справляться с представляющие все наши данные, даже если это крошечная часть населения. Для каждого шага обучения модели будет сдана новая партия.
#
# На практике размер пакета 32 и 64 подходит. Запустите ячейку ниже, чтобы увидеть, с какими пакетами мы будем обучать нашу модель. Является ли наш рандомизатор достаточно случайным? Все ли изображения являются узнаваемыми буквами ASL?

# %%
import matplotlib.pyplot as plt
import numpy as np
batch_size = 32
img_iter = datagen.flow(x_train, y_train, batch_size=batch_size)

x, y = img_iter.next()
fig, ax = plt.subplots(nrows=4, ncols=8)
for i in range(batch_size):
    image = x[i]
    ax.flatten()[i].imshow(np.squeeze(image))
plt.show()

# %% [markdown]
# ## Fitting the Data to the Generator

# %% [markdown]
# Next, the generator must be fit on the training dataset.

# %%
datagen.fit(x_train)

# %% [markdown]
# ## Compiling the Model

# %% [markdown]
# With the data generator instance created and fit to the training data, the model can now be compiled in the same way as our earlier examples:

# %% [markdown]
# Когда экземпляр генератора данных создан и соответствует обучающим данным, теперь модель можно скомпилировать так же, как в наших предыдущих примерах:

# %%
model.compile(loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## Training with Augmentation

# %% [markdown]
# When using an image data generator with Keras, a model trains a bit differently: instead of just passing the `x_train` and `y_train` datasets into the model, we pass the generator in, calling the generator's [flow](https://keras.io/api/preprocessing/image/) method. This causes the images to get augmented live and in memory right before they are passed into the model for training.
#
# Generators can supply an indefinite amount of data, and when we use them to train our data, we need to explicitly set how long we want each epoch to run, or else the epoch will go on indefinitely, with the generator creating an indefinite number of augmented images to provide the model.
#
# We explicitly set how long we want each epoch to run using the `steps_per_epoch` named argument. Because `steps * batch_size = number_of_images_trained in an epoch` a common practice, that we will use here, is to set the number of steps equal to the non-augmented dataset size divided by the batch_size (which has a default value of 32).
#
# Run the following cell to see the results. The training will take longer than before, which makes sense given we are now training on more data than previously:

# %% [markdown]
# При использовании генератора данных изображения с Keras модель обучается немного по-другому: вместо того, чтобы просто передавать наборы данных `x_train` и `y_train` в модель, мы передаем генератор, вызывая [flow] генератора (https:// keras.io/api/preprocessing/image/). Это приводит к тому, что изображения увеличиваются в реальном времени и в памяти прямо перед тем, как они передаются в модель для обучения.
#
# Генераторы могут предоставлять неопределенное количество данных, и когда мы используем их для обучения наших данных, нам нужно явно указать, как долго мы хотим, чтобы работала каждая эпоха, иначе эпоха будет продолжаться бесконечно, а генератор создаст неопределенное количество дополненные изображения для предоставления модели.
#
# Мы явно устанавливаем, как долго мы хотим, чтобы каждая эпоха работала, используя именованный аргумент `steps_per_epoch`. Поскольку `steps * batch_size = number_of_images_trained in a epoch', обычная практика, которую мы будем использовать здесь, заключается в том, чтобы установить количество шагов, равное размеру нерасширенного набора данных, деленному на batch_size (значение по умолчанию равно 32).
#
# Запустите следующую ячейку, чтобы увидеть результаты. Обучение займет больше времени, чем раньше, что имеет смысл, учитывая, что теперь мы тренируемся на большем количестве данных, чем раньше:

# %%
model.fit(img_iter,
          epochs=10,
          steps_per_epoch=len(x_train)/batch_size, # Run same number of steps we would if we were not using a generator.
          validation_data=(x_valid, y_valid))
# Out:
# Epoch 1/10
# 858/857 [==============================] - 10s 12ms/step - loss: 1.0486 - accuracy: 0.6652 - val_loss: 0.6825 - val_accuracy: 0.7766
# Epoch 2/10
# 858/857 [==============================] - 9s 10ms/step - loss: 0.3042 - accuracy: 0.8953 - val_loss: 0.1471 - val_accuracy: 0.9446
# Epoch 3/10
# 858/857 [==============================] - 9s 11ms/step - loss: 0.1926 - accuracy: 0.9349 - val_loss: 0.3793 - val_accuracy: 0.8879
# Epoch 4/10
# 858/857 [==============================] - 9s 10ms/step - loss: 0.1540 - accuracy: 0.9517 - val_loss: 0.0747 - val_accuracy: 0.9682
# Epoch 5/10
# 858/857 [==============================] - 8s 10ms/step - loss: 0.1254 - accuracy: 0.9596 - val_loss: 0.0968 - val_accuracy: 0.9689
# Epoch 6/10
# 858/857 [==============================] - 9s 10ms/step - loss: 0.1127 - accuracy: 0.9643 - val_loss: 0.3368 - val_accuracy: 0.9045
# Epoch 7/10
# 858/857 [==============================] - 8s 10ms/step - loss: 0.0981 - accuracy: 0.9697 - val_loss: 0.2657 - val_accuracy: 0.9134
# Epoch 8/10
# 858/857 [==============================] - 8s 10ms/step - loss: 0.0936 - accuracy: 0.9715 - val_loss: 0.1998 - val_accuracy: 0.9345
# Epoch 9/10
# 858/857 [==============================] - 9s 10ms/step - loss: 0.0786 - accuracy: 0.9752 - val_loss: 0.0485 - val_accuracy: 0.9803
# Epoch 10/10
# 858/857 [==============================] - 9s 11ms/step - loss: 0.0743 - accuracy: 0.9765 - val_loss: 0.0122 - val_accuracy: 0.9958

# %% [markdown]
# ## Discussion of Results

# %% [markdown]
# You will notice that the validation accuracy is higher, and more consistent. This means that our model is no longer overfitting in the way it was; it generalizes better, making better predictions on new data.

# %% [markdown]
# Вы заметите, что точность проверки выше и более постоянна. Это означает, что наша модель больше не переоснащается, как это было раньше; он лучше обобщает, делая лучшие прогнозы на основе новых данных.

# %% [markdown]
# ## Saving the Model

# %% [markdown]
# Now that we have a well-trained model, we will want to deploy it to perform inference on new images.
#
# It is common, once we have a trained model that we are happy with to save it to disk.
#
# Saving the model in Keras is quite easy using the save method. There are different formats that we can save in, but we'll use the default for now. If you'd like, feel free to check out [the documentation](https://www.tensorflow.org/guide/keras/save_and_serialize). In the next notebook, we'll load the model and use it to read new sign language pictures:

# %% [markdown]
# Теперь, когда у нас есть хорошо обученная модель, мы хотим развернуть ее для выполнения логического вывода на новых изображениях.
#
# Обычно, когда у нас есть обученная модель, которой мы довольны, мы сохраняем ее на диск.
#
# Сохранить модель в Keras довольно просто, используя метод сохранения. Существуют разные форматы, в которых мы можем сохранять, но пока мы будем использовать формат по умолчанию. Если хотите, не стесняйтесь ознакомиться с [документацией] (https://www.tensorflow.org/guide/keras/save_and_serialize). В следующем блокноте мы загрузим модель и будем использовать ее для чтения новых изображений на языке жестов:

# %%
model.save('asl_model')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: asl_model/assets

# %% [markdown]
# ## Summary

# %% [markdown]
# In this section you used Keras to augment your dataset, the result being a trained model with less overfitting and excellent validation image results.

# %% [markdown]
# В этом разделе вы использовали Keras для расширения набора данных, в результате чего была получена обученная модель с меньшим переоснащением и отличными результатами проверки изображения.

# %% [markdown]
# ### Clear the Memory
# Before moving on, please execute the following cell to clear up the GPU memory.

# %%
import IPython
app = IPython.Application.instance()
app.kernel.do_shutdown(True)
# Out:
# {'status': 'ok', 'restart': True}

# %% [markdown]
# ## Next

# %% [markdown]
# Now that you have a well-trained model saved to disk, you will, in the next section, deploy it to make predictions on not-yet-seen images.
#
# Please continue to the next notebook: [*Model Predictions*](04b_asl_predictions.ipynb).

# %% [markdown]
# <center><a href="https://www.nvidia.com/dli"> <img src="images/DLI_Header.png" alt="Header" style="width: 400px;"/> </a></center>
